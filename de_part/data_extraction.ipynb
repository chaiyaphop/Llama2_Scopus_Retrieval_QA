# %%
import json
import os
import pandas as pd
from geopy.geocoders import Nominatim


dataset = []
year = os.listdir('./Data 2018-2023/Project/')

geolocator = Nominatim(user_agent='cj')

for y in year:
    file_list = os.listdir(f'./Data 2018-2023/Project/{y}/')
    for file in file_list:
        f = open(f'./Data 2018-2023/Project/{y}/{file}')
        string = f.read()
        f.close()
        data = json.loads(string)
        try:
            authors = ', '.join([au['ce:indexed-name'] for au in data['abstracts-retrieval-response']['authors']['author']])
        except:
            authors = ''
        try:
            title = data['abstracts-retrieval-response']['coredata']['dc:title']
        except:
            title = ''
        try:
            abstracts = data['abstracts-retrieval-response']['item']['bibrecord']['head']['abstracts']
        except:
            abstracts = ''
        try:
            description = data['abstracts-retrieval-response']['coredata']['dc:description']
        except:
            description = ''
        try:
            doi = 'doi:' + data['abstracts-retrieval-response']['coredata']['prism:doi']
        except:
            doi = ''
        try:
            affiliation = data['abstracts-retrieval-response']['affiliation'][0]['affilname']
        except:
            affiliation = ''
        try:
            city = data['abstracts-retrieval-response']['affiliation'][0]['affiliation-city']
            location = geolocator.geocode(city)
            latitude = location.latitude
            longitude = location.longitude
        except:
            city = ''
            latitude = ''
            longitude = ''
        try:
            country = data['abstracts-retrieval-response']['affiliation'][0]['affiliation-country']
        except:
            country = ''

        seq = {
            'authors': authors,
            'title': title,
            'abstracts': abstracts,
            'description': description,
            'doi': doi,
            'affiliation': affiliation,
            'city': city,
            'country': country,
            'latitude': latitude,
            'longitude': longitude
        }
        dataset.append(seq)
df = pd.DataFrame(dataset)
df.to_csv('data_2018_2023.csv', sep='|', index=False)
# Out:
# /Users/t1ct1ch20284633/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df
# Out:
#                                                  authors  \
# 0      Rujitharanawong C., Tuchinda P., Chularojanamo...
# 1                       Rungruengkultorn P., Boonsiri S.
# 2      Muangnapoh C., Tamboon E., Supha N., Toyting J...
# 3      Prasitlumkum N., Chokesuwattanaskul R., Cheung...
# 4      Limskul D., Apinun J., Huanmanop T., Kuptnirat...
# ...                                                  ...
# 20211  Kongkam P., Jaruvongvanich V., Ave K., Aniwan ...
# 20212                    Phetcharakarn K., Senivongse T.
# 20213  Taechajongjintana M., Kasetsuwan N., Reinprayo...
# 20214          Pansa-Ngat P., Jedsukontorn T., Hunsom M.
# 20215  Sio T.T., Prayongrat A., Zhang Y., Lin Q., Xu ...
#
#                                                    title  \
# 0      Direct immunofluorescence staining patterns co...
# 1      Warehouse Processes Improvement Using Lean Six...
# 2      Multilocus Sequence Typing and Virulence Poten...
# 3      Atrial fibrillation ablation in hemodialysis p...
# 4      Anatomy of the coracoid process in Thais: Cada...
# ...                                                  ...
# 20211  Multi-detector computed tomography versus endo...
# 20212  Heuristic-based usability evaluation tool for ...
# 20213  Effectiveness of voriconazole and corneal cros...
# 20214  Optimal hydrogen production coupled with pollu...
# 20215  The Road Less Traveled: Should We Omit Prophyl...
#
#                                                abstracts  \
# 0      © 2021 British Association of Dermatologists.T...
# 1      © 2022. All Rights Reserved.Warehouse processe...
# 2      Copyright © 2022 Muangnapoh et al.Vibrio parah...
# 3                                                   None
# 4      © 2022 The AuthorsIntroduction: The aim of thi...
# ...                                                  ...
# 20211  © 2018, Medical Association of Thailand. All r...
# 20212  © Springer International Publishing AG 2018.He...
# 20213  © 2018 The Author(s).Background: We report a r...
# 20214  © 2018 by the authors. Licensee MDPI, Basel, S...
# 20215  © 2018 Elsevier Inc.New randomized data from J...
#
#                                              description  \
# 0      This retrospective study performed to investig...
# 1      Warehouse processes are the primary activities...
# 2      Vibrio parahaemolyticus is a Gram-negative, fo...
# 3
# 4      Introduction: The aim of this study was to inv...
# ...                                                  ...
# 20211  Objective: Endoscopic ultrasonography [EUS] ha...
# 20212  Heuristic evaluation is a popular method for e...
# 20213  Background: We report a rare case of Phialopho...
# 20214  This work aimed to produce hydrogen (H2) simul...
# 20215  New randomized data from Japan have raised que...
#
#                                     doi  \
# 0                 doi:10.1111/ced.14879
# 1
# 2         doi:10.1128/spectrum.00886-22
# 3              doi:10.21037/apm-22-1041
# 4        doi:10.1016/j.tria.2022.100168
# ...                                 ...
# 20211
# 20212  doi:10.1007/978-3-319-64051-8_10
# 20213     doi:10.1186/s13256-018-1765-1
# 20214           doi:10.3390/nano8020096
# 20215    doi:10.1016/j.cllc.2018.03.006
#
#                                              affiliation       city  \
# 0                                       Siriraj Hospital    Bangkok
# 1
# 2               Mahidol University, Faculty of Dentistry    Bangkok
# 3                    University of California, Riverside  Riverside
# 4
# ...                                                  ...        ...
# 20211               King Chulalongkorn Memorial Hospital    Bangkok
# 20212
# 20213
# 20214                           Chulalongkorn University    Bangkok
# 20215  Shandong First Medical University &amp; Shando...
#
#              country   latitude   longitude
# 0           Thailand   13.82458  100.622446
# 1
# 2           Thailand   13.82458  100.622446
# 3      United States  33.721999 -116.037247
# 4
# ...              ...        ...         ...
# 20211       Thailand   13.82458  100.622446
# 20212
# 20213
# 20214       Thailand   13.82458  100.622446
# 20215          China
#
# [20216 rows x 10 columns]

# %%
df_test = pd.read_csv('data_2018_2023.csv', sep='|')

# %%
df_test
# Out:
#                                                  authors  \
# 0      Rujitharanawong C., Tuchinda P., Chularojanamo...
# 1                       Rungruengkultorn P., Boonsiri S.
# 2      Muangnapoh C., Tamboon E., Supha N., Toyting J...
# 3      Prasitlumkum N., Chokesuwattanaskul R., Cheung...
# 4      Limskul D., Apinun J., Huanmanop T., Kuptnirat...
# ...                                                  ...
# 20211  Kongkam P., Jaruvongvanich V., Ave K., Aniwan ...
# 20212                    Phetcharakarn K., Senivongse T.
# 20213  Taechajongjintana M., Kasetsuwan N., Reinprayo...
# 20214          Pansa-Ngat P., Jedsukontorn T., Hunsom M.
# 20215  Sio T.T., Prayongrat A., Zhang Y., Lin Q., Xu ...
#
#                                                    title  \
# 0      Direct immunofluorescence staining patterns co...
# 1      Warehouse Processes Improvement Using Lean Six...
# 2      Multilocus Sequence Typing and Virulence Poten...
# 3      Atrial fibrillation ablation in hemodialysis p...
# 4      Anatomy of the coracoid process in Thais: Cada...
# ...                                                  ...
# 20211  Multi-detector computed tomography versus endo...
# 20212  Heuristic-based usability evaluation tool for ...
# 20213  Effectiveness of voriconazole and corneal cros...
# 20214  Optimal hydrogen production coupled with pollu...
# 20215  The Road Less Traveled: Should We Omit Prophyl...
#
#                                                abstracts  \
# 0      © 2021 British Association of Dermatologists.T...
# 1      © 2022. All Rights Reserved.Warehouse processe...
# 2      Copyright © 2022 Muangnapoh et al.Vibrio parah...
# 3                                                    NaN
# 4      © 2022 The AuthorsIntroduction: The aim of thi...
# ...                                                  ...
# 20211  © 2018, Medical Association of Thailand. All r...
# 20212  © Springer International Publishing AG 2018.He...
# 20213  © 2018 The Author(s).Background: We report a r...
# 20214  © 2018 by the authors. Licensee MDPI, Basel, S...
# 20215  © 2018 Elsevier Inc.New randomized data from J...
#
#                                              description  \
# 0      This retrospective study performed to investig...
# 1      Warehouse processes are the primary activities...
# 2      Vibrio parahaemolyticus is a Gram-negative, fo...
# 3                                                    NaN
# 4      Introduction: The aim of this study was to inv...
# ...                                                  ...
# 20211  Objective: Endoscopic ultrasonography [EUS] ha...
# 20212  Heuristic evaluation is a popular method for e...
# 20213  Background: We report a rare case of Phialopho...
# 20214  This work aimed to produce hydrogen (H2) simul...
# 20215  New randomized data from Japan have raised que...
#
#                                     doi  \
# 0                 doi:10.1111/ced.14879
# 1                                   NaN
# 2         doi:10.1128/spectrum.00886-22
# 3              doi:10.21037/apm-22-1041
# 4        doi:10.1016/j.tria.2022.100168
# ...                                 ...
# 20211                               NaN
# 20212  doi:10.1007/978-3-319-64051-8_10
# 20213     doi:10.1186/s13256-018-1765-1
# 20214           doi:10.3390/nano8020096
# 20215    doi:10.1016/j.cllc.2018.03.006
#
#                                              affiliation       city  \
# 0                                       Siriraj Hospital    Bangkok
# 1                                                    NaN        NaN
# 2               Mahidol University, Faculty of Dentistry    Bangkok
# 3                    University of California, Riverside  Riverside
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 20211               King Chulalongkorn Memorial Hospital    Bangkok
# 20212                                                NaN        NaN
# 20213                                                NaN        NaN
# 20214                           Chulalongkorn University    Bangkok
# 20215  Shandong First Medical University &amp; Shando...     Tai'an
#
#              country   latitude   longitude
# 0           Thailand  13.824580  100.622446
# 1                NaN        NaN         NaN
# 2           Thailand  13.824580  100.622446
# 3      United States  33.721999 -116.037247
# 4                NaN        NaN         NaN
# ...              ...        ...         ...
# 20211       Thailand  13.824580  100.622446
# 20212            NaN        NaN         NaN
# 20213            NaN        NaN         NaN
# 20214       Thailand  13.824580  100.622446
# 20215          China  36.200297  117.080932
#
# [20216 rows x 10 columns]
