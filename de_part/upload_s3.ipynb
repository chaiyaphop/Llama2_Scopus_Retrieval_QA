# %% [markdown]
# https://boto3.amazonaws.com/v1/documentation/api/latest/guide/s3-uploading-files.html

# %%
import boto3

# %%
s3_client = boto3.client('s3')
s3_client.upload_file("./data_2018_2023.csv", "dsde-tools-project", "./data/data_2018_2023.csv")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# d:\iCloudDrive\CU\Courses\2110531_DS&DE_Tools\Final_Project\upload_s3.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/d%3A/iCloudDrive/CU/Courses/2110531_DS%26DE_Tools/Final_Project/upload_s3.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> s3_client = boto3.client('s3')
# ----> <a href='vscode-notebook-cell:/d%3A/iCloudDrive/CU/Courses/2110531_DS%26DE_Tools/Final_Project/upload_s3.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> s3_client.upload_file("./data_2018_2023.csv", "dsde-tools-project", "./data/data_2018_2023.csv")
#
# File c:\Users\CJ\anaconda3\Lib\site-packages\boto3\s3\inject.py:143, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     108 """Upload a file to an S3 object.
#     109
#     110 Usage::
#    (...)
#     140     transfer.
#     141 """
#     142 with S3Transfer(self, Config) as transfer:
# ...
